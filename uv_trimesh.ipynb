# %%
import numpy as np
import trimesh
import matplotlib.pyplot as plt

# %%
mesh_obj_path = 'demo_data/hrach/test2_0.obj'

# %%
mesh = trimesh.load(mesh_obj_path)

# %%
uv = mesh.vertices[:, :2]
mesh.visual.uv = uv

# %%
uv_coords = mesh.visual.uv

plt.scatter(uv_coords[:, 0], uv_coords[:, 1], s=2)
